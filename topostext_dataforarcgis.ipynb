# %%
import requests
from bs4 import BeautifulSoup

# %%
soup = BeautifulSoup(requests.get('https://topostext.org/work/126').text) ## APOLLONIUS RHODIUS, ARGONAUTICA

# %%
import collections 
places_dict = {}
freq_dict = collections.defaultdict(int)
for i, a in enumerate(soup.find_all('a')):
  if ('about' in a.attrs.keys()):
    places_dict[a.text] = (a['about'], a['class'], a['lat'], a['long'])
    freq_dict[a.text] += 1

# %%
import pandas as pd
place_df = pd.DataFrame.from_dict(places_dict, orient='index').reset_index().rename(columns={'index':'place_name', 0:'topos_url', 1: 'type', 2:'lat', 3:'long'})
freq_df  = pd.DataFrame.from_dict(freq_dict, orient='index').reset_index().rename(columns={'index':'place_name', 0:'frequency'})

# %%
place_freq = pd.merge(place_df, freq_df, on='place_name')
place_freq['type'] = place_freq['type'].apply(lambda x: x[0])
place_freq = place_freq.drop(place_freq.loc[place_freq['type'] == 'person'].index)

# %%
place_freq
# Out:
#            place_name                               topos_url     type  \
# 0              Pontus  https://topostext.org/place/435335WPon    place
# 1       Cyanean rocks  https://topostext.org/place/412291IKya    place
# 2             Anaurus  https://topostext.org/place/393228WAna    place
# 3           Pelasgian  https://topostext.org/place/398223UPel  demonym
# 4    Pimpleian height  https://topostext.org/place/401225UPim    place
# ..                ...                                     ...      ...
# 278       Tyrrhenians  https://topostext.org/place/430105RTyr   ethnic
# 279             Thera  https://topostext.org/place/364255PThe    place
# 280             Aulis  https://topostext.org/place/384236UAul    place
# 281          Opuntian  https://topostext.org/place/386231ROpu  demonym
# 282          Locrians  https://topostext.org/place/386231ROpu   ethnic
#
#          lat      long  frequency
# 0       43.5      33.5          8
# 1     41.234  29.11517          5
# 2     39.365    22.899          2
# 3       39.5      22.5          7
# 4    40.1434   22.4931          1
# ..       ...       ...        ...
# 278       43      10.5          1
# 279   36.364    25.477          1
# 280  38.4335   23.5925          1
# 281    38.65     23.04          1
# 282    38.65     23.04          1
#
# [271 rows x 6 columns]

# %%
na = pd.read_csv('/content/names.csv') ## place name look up
pl = pd.read_csv('/content/places.csv') ## coord look up
pt = pd.read_csv('/content/places_place_types.csv') ## place type look up

# %%
def get_place(pl_id):
    pl_url = f'https://pleiades.stoa.org/places/{pl_id}/json'
    r = requests.get(pl_url)
    try:
      return r.json()
    except:
      return None

def get_pleiades(topos_url):
  links = BeautifulSoup(requests.get(topos_url).text).find_all('a', {'target':'_blank'})
  pl_id = ''
  for a in links:
    if 'Pleiades' in a.text:
      pl_id += a['href'].split('/')[-1]
  try: 
    return get_place(pl_id)
  except ChunkedEncodingError:
    return None

# %%
from tqdm import tqdm
tqdm.pandas()

place_freq['pl_json'] = place_freq['topos_url'].progress_apply(get_pleiades)
# Out:
# 100%|██████████| 271/271 [04:28<00:00,  1.01it/s]

# %%
place_freq['pl_romanized'] = place_freq['pl_json'].apply(lambda x: x['names'][-1]['romanized'] if (len(x) == 26) and (len(x['names']) > 0) else None)

# %%
# number of entiries with wiht no romanized name
len(place_freq.loc[place_freq['pl_romanized'].isnull()])
# Out:
# 15

# %%
place_freq['pl_attested'] = place_freq['pl_json'].apply(lambda x: x['names'][-1]['attested'] if (len(x) == 26) and (len(x['names']) > 0) else None)

# %%
place_freq['pl_type'] = place_freq['pl_json'].apply(lambda x: x['placeTypes'][0] if 'placeTypes' in x.keys() else None)

# %%
place_freq = place_freq.drop(['pl_json'], axis=1)

# %%
place_freq.to_csv('argo_place_freq.csv')

# %%
## Final functions
import requests
from bs4 import BeautifulSoup
import collections 
import pandas as pd
import re
from tqdm import tqdm
tqdm.pandas()

def get_place(pl_id):
    pl_url = f'https://pleiades.stoa.org/places/{pl_id}/json'
    r = requests.get(pl_url)
    try:
      return r.json()
    except:
      return None

def get_pleiades(topos_url):
  links = BeautifulSoup(requests.get(topos_url).text).find_all('a', {'target':'_blank'})
  pl_id = ''
  for a in links:
    if 'Pleiades' in a.text:
      pl_id += a['href'].split('/')[-1]
  try: 
    return get_place(pl_id)
  except:
    return None

def resolve_points(df, pl_id):
  pl_id = df['pl_id'].loc[df['pl_id'] == pl_id].iloc[0]
  sim = df.loc[df['pl_id'] == pl_id]
  if len(sim) > 1:
    spn = sim.place_name.max() ## picking shortest name...
    gold = df.loc[df['place_name'] == spn]
    dross = sim.drop(gold.index)
    s = sum(sim.frequency.to_list())
    df['frequency'][df['place_name'] == spn] = s
    df = df.drop(dross.index)
  df = df.reset_index(drop=True)
  return df

def resolve_types(pl_type):
  if (pl_type == 'unknown') or (pl_type == 'unlocated'):
    return 'Mythic site'
  elif (pl_type == 'label') or (pl_type == None):
    return 'Tribe'
  elif (pl_type == 'cape') or (pl_type == 'island') or (pl_type == 'archipelago') or (pl_type == 'peninsula'):
    return 'Coastal feature'
  elif (pl_type == 'water-open') or (pl_type == 'river'):
    return 'Waterway'
  elif (pl_type == 'sanctuary'):
    return 'Temple'
  elif (pl_type == 'urban') or (pl_type == 'settlement'):
    return 'Political entity' 
  else:
    return pl_type.title()

def fill_in_attested(place_name, pl_attested):
  attested = []
  if (pl_attested != '') and (not isinstance(pl_attested, type(None))):
    attested.append(pl_attested)
  if not place_name in attested:
    attested.append(place_name)
  return attested

def fill_in_attested_from_pl_title(title, pl_attested):
  attested = pl_attested
  if '/' in title:
    for name in title.split('/'):
      pl_attested.append(name)
  return list(set(attested))

def getDataForArcGis(topos_url):
  soup = BeautifulSoup(requests.get(topos_url).text)

  text_name = soup.find('h2').text.split(',')
  print(f'Reading{text_name[1]} by {text_name[0]}...')

  places_dict = {}
  freq_dict = collections.defaultdict(int)
  for i, a in enumerate(soup.find_all('a')):
    if ('about' in a.attrs.keys()):
      places_dict[a.text] = (a['about'], a['class'], a['lat'], a['long'])
      freq_dict[a.text] += 1

  place_df = pd.DataFrame.from_dict(places_dict, orient='index').reset_index().rename(columns={'index':'place_name', 0:'topos_url', 1: 'type', 2:'lat', 3:'long'})
  freq_df  = pd.DataFrame.from_dict(freq_dict, orient='index').reset_index().rename(columns={'index':'place_name', 0:'frequency'})

  place_freq = pd.merge(place_df, freq_df, on='place_name')
  place_freq['type'] = place_freq['type'].apply(lambda x: x[0])
  place_freq = place_freq.drop(place_freq.loc[place_freq['type'] == 'person'].index)

  print("Querying Pleiades.")
  place_freq['pl_json'] = place_freq['topos_url'].progress_apply(get_pleiades)
  place_freq = place_freq.drop(place_freq.loc[place_freq['pl_json'].isnull()].index)
  place_freq['pl_id'] = place_freq['pl_json'].apply(lambda x: x['id'] if bool(re.search(r'\d',x['id'])) else None)
  place_freq['title'] = place_freq['pl_json'].apply(lambda x: x['title'].split('/')[0] if '/' in x['title'] else x['title'])
  place_freq['title'] = place_freq.apply(lambda x: x['place_name'] if x['pl_id'] == None else x['title'], axis=1)
  place_freq['pl_romanized'] = place_freq['pl_json'].apply(lambda x: x['names'][-1]['romanized'] if (len(x) == 26) and (len(x['names']) > 0) else None)
  place_freq['pl_attested'] = place_freq['pl_json'].apply(lambda x: x['names'][-1]['attested'] if (len(x) == 26) and (len(x['names']) > 0) else None)
  place_freq['pl_attested'] = place_freq.apply(lambda x: fill_in_attested(x['place_name'], x['pl_attested']), axis=1)
  place_freq['pl_attested'] = place_freq.apply(lambda x: fill_in_attested_from_pl_title(x['title'], x['pl_attested']), axis=1)
  place_freq['pl_type'] = place_freq['pl_json'].apply(lambda x: x['placeTypes'][0] if 'placeTypes' in x.keys() else None)
  place_freq['pl_type'] = place_freq['pl_type'].apply(resolve_types)
  place_freq = place_freq.drop(['pl_json'], axis=1)

  return place_freq, text_name

def outputData(topos_url):
  df, text_name = getDataForArcGis(topos_url)
  for pl_id in df.pl_id.to_list():
    try:
      df = resolve_points(df, pl_id) ## single positional index out of bounds error, not sure why...
    except:
      pass
  author = text_name[0].replace(' ','')
  text_title = text_name[1].replace(' ','').strip()
  df.to_csv(f'{author}_{text_title}_gisdata.csv')
  return df

# %%
mi = outputData('https://topostext.org/work/791')
# Out:
# Reading Misopogon by Julian the Emperor...
# Querying Pleiades.
# 100%|██████████| 44/44 [00:23<00:00,  1.84it/s]
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
mi
# Out:
#       place_name                               topos_url     type       lat  \
# 0          Paros  https://topostext.org/place/371252PPar    place   37.0844
# 1          Rhine  https://topostext.org/place/507071WRhi    place    50.736
# 2          Celts  https://topostext.org/place/490070RKel   ethnic        49
# 3        Parisii  https://topostext.org/place/489023ULut   ethnic   48.8529
# 4        Phrygia  https://topostext.org/place/400310RPhr    place        40
# 5        Lydians  https://topostext.org/place/385280RLyd   ethnic      38.5
# 6       Persians  https://topostext.org/place/295540RPer   ethnic      29.5
# 7        Pythian  https://topostext.org/place/385225SDel  demonym  38.48264
# 8           Troy  https://topostext.org/place/400262UIli    place   39.9575
# 9         Daphne  https://topostext.org/place/361361UDap    place     36.13
# 10         Samos  https://topostext.org/place/377269PSam    place    37.695
# 11     Athenians  https://topostext.org/place/380237PAth   ethnic   37.9718
# 12         Arabs  https://topostext.org/place/280400RAra   ethnic        28
# 13     Thracians  https://topostext.org/place/410265RThr   ethnic        41
# 14     Paeonians  https://topostext.org/place/415220RPai   ethnic      41.5
# 15       Mysians  https://topostext.org/place/440205RMys   ethnic        44
# 16        Danube  https://topostext.org/place/442277WIst    place    44.206
# 17     Illyrians  https://topostext.org/place/405195RIll   ethnic      40.8
# 18        Ithaca  https://topostext.org/place/383204UIth    place    38.453
# 19      Marathon  https://topostext.org/place/381240DMar    place   38.1466
# 20     Acharnian  https://topostext.org/place/381237DAch  demonym   38.0803
# 21         Delos  https://topostext.org/place/374253SSan    place   37.4004
# 22      Scythian  https://topostext.org/place/475310RSky  demonym      47.5
# 23      Tarentum  https://topostext.org/place/405172PTar    place    40.476
# 24          Rome  https://topostext.org/place/419125PRom    place    41.891
# 25         Emesa  https://topostext.org/place/347367UEme    place   34.7239
# 26    Galilaeans  https://topostext.org/place/328353RGal   ethnic      32.8
# 27      Bithynia  https://topostext.org/place/405295RBit    place      40.5
# 28    Chaeroneia  https://topostext.org/place/385228PCha    place   38.4944
# 29     Hercynian  https://topostext.org/place/484084RHer    place     48.35
# 30   Cappadocian  https://topostext.org/place/388350RCap  demonym      38.8
# 31        Pontus  https://topostext.org/place/435335WPon    place      43.5
# 32       Abantes  https://topostext.org/place/388238RAba   ethnic     38.75
# 33          Teos  https://topostext.org/place/382268PTeo    place   38.1717
# 34        Market  https://topostext.org/place/380237XAgo    place    37.975
# 35  Alexandrians  https://topostext.org/place/312299PAle   ethnic    31.182
# 36         Egypt  https://topostext.org/place/271307REgy    place      27.1
# 37       Chalcis  https://topostext.org/place/360370UCha    place   35.9878
# 38    Hierapolis  https://topostext.org/place/365379UHie    place    36.527
# 39      Boeotian  https://topostext.org/place/384233RBoi  demonym     38.35
#
#         long  frequency      pl_id                         title  \
# 0    25.1483          1     599867                         Paros
# 1     7.1111          1     109277                Rhenus (river)
# 2          7         11       None                         Celts
# 3     2.3499          2     109126                       Lutetia
# 4         31          1     609502                       Phrygia
# 5         28          1     550701                         Lydia
# 6         54          1     922698                        Persis
# 7   22.50108          1     540726                        Delphi
# 8    26.2389          2     550595                         Ilium
# 9    36.1442          6     658450                        Daphne
# 10    26.935          1     599925                         Samos
# 11  23.72793          4     579885                       Athenae
# 12        40          1     746710               Arabia Eudaemon
# 13      26.5          4     501638                       Thracia
# 14     22.01          2     491680                       Paionia
# 15      20.5          1       1136               Moesia Superior
# 16    27.742          1     226577                      Danuvius
# 17      19.8          1     481866                       Illyrii
# 18    20.643          1     530906               Ithaca (island)
# 19   23.9701          1     580021                      Marathon
# 20   23.7332          1     579842                  Acharnai (N)
# 21   25.2666          1     599506  Sanctuary of Apollo on Delos
# 22     31.01          1       1273                       Scythia
# 23    17.228          2     442810                         Taras
# 24    12.486          4     423025                          Roma
# 25   36.7143          2     668261                      (H)Emesa
# 26     35.25          2     678145                      Galilaea
# 27      29.5          1     511189             Bithynia (region)
# 28   22.8416          1     540701                     Chaeronea
# 29      8.35          1     123090                Hercynia Silva
# 30        35          1     628949           Cappadocia (region)
# 31      33.5          1       1224                Pontus Euxinus
# 32      23.5          1     540583                       Abantes
# 33   26.7877          1     550913                          Teos
# 34    23.723          1  807514119               Agora of Athens
# 35    29.897          1     727070                    Alexandria
# 36      30.7          2     981503        Ancient Egypt (region)
# 37   37.0432          1     668226              Chalcis ad Belum
# 38   37.9477          1     658480                    Hierapolis
# 39     23.25          1     540689                       Boeotia
#
#                            pl_romanized                  pl_attested  \
# 0                                 Paros                      [Paros]
# 1                                Rhenus                      [Rhine]
# 2                                  None                      [Celts]
# 3                               Lutezia           [Lutezia, Parisii]
# 4                            Berekyntes                    [Phrygia]
# 5                               Maionia                    [Lydians]
# 6                                  Pars                   [Persians]
# 7                                 Delfi             [Pythian, Delfi]
# 8                          Troía, Troia                [Troy, Τροία]
# 9                                Daphne              [Δάφνη, Daphne]
# 10                                Samos                      [Samos]
# 11                                Athen           [Athenians, Athen]
# 12                     Arabias euporion   [Arabs, Ἀραβίας ᾿ευπόριον]
# 13                              Thracia                  [Thracians]
# 14                              Paiones                  [Paeonians]
# 15                      Moesia Superior                    [Mysians]
# 16                               Danube                     [Danube]
# 17                              Illyrii                  [Illyrians]
# 18                               Ithaca              [Ἰθάκη, Ithaca]
# 19                   Marathṓn, Marathon          [Μαραθών, Marathon]
# 20                             Acharnes        [Acharnés, Acharnian]
# 21                           Apollo, T.                      [Delos]
# 22                              Skythai                   [Scythian]
# 23                              Oebalia                   [Tarentum]
# 24                   Rhome, Rhṓmē, Rome                 [Ῥώμῃ, Rome]
# 25                           Colonia H.                      [Emesa]
# 26                             Galilaia       [Γαλιλαίᾳ, Galilaeans]
# 27                             Bithynia                   [Bithynia]
# 28                            Chaeronea      [Χαιρώνεια, Chaeroneia]
# 29                       Hercynia Silva  [Hercynia Silva, Hercynian]
# 30                           Cappadocia                [Cappadocian]
# 31                     Pontike Thalatta    [Pontus, Ποντική Θάλαττα]
# 32                              Abantes                    [Abantes]
# 33                                 Teos                       [Teos]
# 34                                Agora              [Agora, Market]
# 35              Alexandreia ad Aegyptum               [Alexandrians]
# 36                             Aegyptus            [Aegyptus, Egypt]
# 37  Qinnasrin, Qinasrin, bfSQjf, qnsryn            [قنسرين, Chalcis]
# 38                               Mabbuk                 [Hierapolis]
# 39                     Boiōtía, Boiotia          [Boeotian, Βοιωτία]
#
#              pl_type
# 0   Political entity
# 1           Waterway
# 2              Tribe
# 3   Political entity
# 4             Region
# 5             Region
# 6              Tribe
# 7             Temple
# 8   Political entity
# 9   Political entity
# 10  Political entity
# 11  Political entity
# 12   Coastal feature
# 13            Region
# 14             Tribe
# 15       Mythic site
# 16          Waterway
# 17             Tribe
# 18   Coastal feature
# 19  Political entity
# 20  Political entity
# 21            Temple
# 22            Region
# 23  Political entity
# 24  Political entity
# 25  Political entity
# 26            Region
# 27            Region
# 28  Political entity
# 29       Mythic site
# 30            Region
# 31          Waterway
# 32             Tribe
# 33  Political entity
# 34             Plaza
# 35  Political entity
# 36            Region
# 37  Political entity
# 38  Political entity
# 39            Region

# %%
ar = outputData('https://topostext.org/work/126')
# Out:
# Reading Argonautica by Apollonius Rhodius...
# Querying Pleiades.
# 100%|██████████| 271/271 [02:25<00:00,  1.87it/s]
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
ar
# Out:
#            place_name                               topos_url     type  \
# 0              Pontus  https://topostext.org/place/435335WPon    place
# 1       Cyanean rocks  https://topostext.org/place/412291IKya    place
# 2             Anaurus  https://topostext.org/place/393228WAna    place
# 3    Pimpleian height  https://topostext.org/place/401225UPim    place
# 4                Zone  https://topostext.org/place/409256PZon    place
# ..                ...                                     ...      ...
# 228            Anaphe  https://topostext.org/place/364258PAna    place
# 229       Tyrrhenians  https://topostext.org/place/430105RTyr   ethnic
# 230             Thera  https://topostext.org/place/364255PThe    place
# 231             Aulis  https://topostext.org/place/384236UAul    place
# 232          Opuntian  https://topostext.org/place/386231ROpu  demonym
#
#          lat      long  frequency   pl_id            title      pl_romanized  \
# 0       43.5      33.5          8    1224   Pontus Euxinus  Pontike Thalatta
# 1     41.234  29.11517          5  521064    Kyaneai Inss.           Kyaneai
# 2     39.365    22.899          2  540634  Anauros (river)           Anauros
# 3    40.1434   22.4931          1  491697         Pimpleia          Pimpleia
# 4    40.8635   25.6382          1  501667             Zone              Zone
# ..       ...       ...        ...     ...              ...               ...
# 228   36.359    25.799          3  599491           Anaphe            Anaphe
# 229       43      10.5          5  413122          Etruria             Rasna
# 230   36.364    25.477          3  599971            Thera             Thera
# 231  38.4335   23.5925          1  579889            Aulis             Aulis
# 232    38.65     23.04          2  540918   Locris Opuntia    Locris Opuntia
#
#                    pl_attested           pl_type
# 0    [Pontus, Ποντική Θάλαττα]          Waterway
# 1              [Cyanean rocks]   Coastal feature
# 2                    [Anaurus]          Waterway
# 3           [Pimpleian height]  Political entity
# 4                       [Zone]  Political entity
# ..                         ...               ...
# 228                   [Anaphe]  Political entity
# 229              [Tyrrhenians]            Region
# 230                    [Thera]  Political entity
# 231                    [Aulis]  Political entity
# 232                 [Opuntian]            Region
#
# [233 rows x 11 columns]

# %%
il = outputData('https://topostext.org/work/2')
# Out:
# Reading Iliad by Homer...
# Querying Pleiades.
# 100%|██████████| 317/317 [02:48<00:00,  1.88it/s]
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
il.sort_values('frequency', ascending=False)
# Out:
#     place_name                               topos_url    type       lat  \
# 6         Troy  https://topostext.org/place/400262UIli   place   39.9575
# 1        Argos  https://topostext.org/place/376227PArg   place  37.63091
# 0      Olympus  https://topostext.org/place/401224LOly   place   40.0856
# 221    Lycians  https://topostext.org/place/365295RLyc  ethnic      36.5
# 193        Ida  https://topostext.org/place/397268LIda   place   39.6922
# ..         ...                                     ...     ...       ...
# 158    Trachis  https://topostext.org/place/388224RTra   place     38.75
# 68    Histiaea  https://topostext.org/place/389231PHis   place   38.9466
# 67     Eretria  https://topostext.org/place/384238PEre   place   38.3982
# 161    Pyrasus  https://topostext.org/place/393228PPyr   place   39.2788
# 273    Sipylus  https://topostext.org/place/386275LSip   place    38.567
#
#          long  frequency   pl_id                         title  pl_romanized  \
# 6     26.2389        800  550595                         Ilium  Troía, Troia
# 1    22.72079        215  570106                         Argos  Árgos, Argos
# 0     22.3586        112  491677  Olympos (mountain in Greece)       Olympus
# 221      29.5         70  638965                         Lycia         Lycia
# 193   26.8423         47  550592                Ida (mountain)           Ida
# ..        ...        ...     ...                           ...           ...
# 158      22.4          1    None                       Trachis          None
# 68    23.0905          1  540817                      Histiaia      Hestiaia
# 67    23.7905          1  579925                       Eretria       Eretria
# 161   22.8212          1  541081                       Pyrasos       Pyrasos
# 273    27.456          1  550884                       Sipylos       Sipylos
#
#             pl_attested           pl_type
# 6         [Troy, Τροία]  Political entity
# 1        [Ἄργος, Argos]  Political entity
# 0             [Olympus]          Mountain
# 221    [Lycians, Lycia]            Region
# 193               [Ida]          Mountain
# ..                  ...               ...
# 158           [Trachis]             Tribe
# 68           [Histiaea]  Political entity
# 67   [Ἐρέτρια, Eretria]  Political entity
# 161  [Πύρασος, Pyrasus]  Political entity
# 273  [Sipylus, Σίπυλος]          Mountain
#
# [274 rows x 11 columns]
